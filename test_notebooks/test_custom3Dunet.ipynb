# %%
from custom3dUnet import build_unet, unet3d_BN
from tensorflow.keras.layers import Input
import numpy as np

# %%
IMG_SIZE = 128
input_layer = Input((64, 192, 192, 1))
model = build_unet(input_layer, 'he_normal')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 192, 19  0           []
#                                 2, 1)]
#
#  conv3d (Conv3D)                (None, 64, 192, 192  448         ['input_1[0][0]']
#                                 , 16)
#
#  dropout (Dropout)              (None, 64, 192, 192  0           ['conv3d[0][0]']
#                                 , 16)
#
#  conv3d_1 (Conv3D)              (None, 64, 192, 192  6928        ['dropout[0][0]']
#                                 , 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 32, 96, 96,   0           ['conv3d_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 32, 96, 96,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 32, 96, 96,   0           ['conv3d_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 32, 96, 96,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 16, 48, 48,   0          ['conv3d_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 16, 48, 48,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  dropout_2 (Dropout)            (None, 16, 48, 48,   0           ['conv3d_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 16, 48, 48,   110656      ['dropout_2[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 8, 24, 24, 6  0          ['conv3d_5[0][0]']
#                                 4)
#
#  conv3d_6 (Conv3D)              (None, 8, 24, 24, 1  221312      ['max_pooling3d_2[0][0]']
#                                 28)
#
#  dropout_3 (Dropout)            (None, 8, 24, 24, 1  0           ['conv3d_6[0][0]']
#                                 28)
#
#  conv3d_7 (Conv3D)              (None, 8, 24, 24, 1  442496      ['dropout_3[0][0]']
#                                 28)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 4, 12, 12, 1  0          ['conv3d_7[0][0]']
#                                 28)
#
#  conv3d_8 (Conv3D)              (None, 4, 12, 12, 2  884992      ['max_pooling3d_3[0][0]']
#                                 56)
#
#  dropout_4 (Dropout)            (None, 4, 12, 12, 2  0           ['conv3d_8[0][0]']
#                                 56)
#
#  conv3d_9 (Conv3D)              (None, 4, 12, 12, 2  1769728     ['dropout_4[0][0]']
#                                 56)
#
#  conv3d_transpose (Conv3DTransp  (None, 8, 24, 24, 1  262272     ['conv3d_9[0][0]']
#  ose)                           28)
#
#  concatenate (Concatenate)      (None, 8, 24, 24, 2  0           ['conv3d_transpose[0][0]',
#                                 56)                               'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 8, 24, 24, 1  884864      ['concatenate[0][0]']
#                                 28)
#
#  dropout_5 (Dropout)            (None, 8, 24, 24, 1  0           ['conv3d_10[0][0]']
#                                 28)
#
#  conv3d_11 (Conv3D)             (None, 8, 24, 24, 1  442496      ['dropout_5[0][0]']
#                                 28)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 16, 48, 48,   65600      ['conv3d_11[0][0]']
#  spose)                         64)
#
#  concatenate_1 (Concatenate)    (None, 16, 48, 48,   0           ['conv3d_transpose_1[0][0]',
#                                 128)                              'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 16, 48, 48,   221248      ['concatenate_1[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 16, 48, 48,   0           ['conv3d_12[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 16, 48, 48,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, 32, 96, 96,   16416      ['conv3d_13[0][0]']
#  spose)                         32)
#
#  concatenate_2 (Concatenate)    (None, 32, 96, 96,   0           ['conv3d_transpose_2[0][0]',
#                                 64)                               'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)             (None, 32, 96, 96,   55328       ['concatenate_2[0][0]']
#                                 32)
#
#  dropout_7 (Dropout)            (None, 32, 96, 96,   0           ['conv3d_14[0][0]']
#                                 32)
#
#  conv3d_15 (Conv3D)             (None, 32, 96, 96,   27680       ['dropout_7[0][0]']
#                                 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 64, 192, 192  4112       ['conv3d_15[0][0]']
#  spose)                         , 16)
#
#  concatenate_3 (Concatenate)    (None, 64, 192, 192  0           ['conv3d_transpose_3[0][0]',
#                                 , 32)                             'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, 64, 192, 192  13840       ['concatenate_3[0][0]']
#                                 , 16)
#
#  dropout_8 (Dropout)            (None, 64, 192, 192  0           ['conv3d_16[0][0]']
#                                 , 16)
#
#  conv3d_17 (Conv3D)             (None, 64, 192, 192  6928        ['dropout_8[0][0]']
#                                 , 16)
#
#  conv3d_18 (Conv3D)             (None, 64, 192, 192  17          ['conv3d_17[0][0]']
#                                 , 1)
#
# ==================================================================================================
# Total params: 5,644,913
# Trainable params: 5,644,913
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# create a fake batch
x = np.random.randint(low=0, high=256, size=(1, 64, 192, 192, 1))
x.shape
# Out:
# (1, 64, 192, 192, 1)

# %%
model(x)
# Out:
# <tf.Tensor: shape=(1, 64, 192, 192, 1), dtype=float32, numpy=
# array([[[[[3.78622543e-26],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [2.01297083e-15]],
#
#          [[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00]],
#
#          [[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00]],
#
#          ...,
#
#          [[6.80999891e-23],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [7.03738187e-31]],
#
#          [[1.10215469e-30],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00]],
#
#          [[9.39305357e-24],
#           [8.55984186e-33],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [5.92970926e-24],
#           [7.15252332e-21]]],
#
#
#         [[[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [1.79348582e-35],
#           [3.32993615e-08]],
#
#          [[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [1.13776375e-11],
#           [2.43803680e-38]],
#
#          [[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [2.77016214e-37],
#           [0.00000000e+00],
#           [6.02181542e-12]],
#
#          ...,
#
#          [[1.47599382e-08],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [2.56922629e-35],
#           [9.12254922e-25]],
#
#          [[4.97069580e-18],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00]],
#
#          [[1.27859437e-31],
#           [1.20553456e-13],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [2.03456407e-37],
#           [0.00000000e+00]]],
#
#
#         [[[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [8.71807010e-37],
#           [2.36755518e-31],
#           [7.38626361e-01]],
#
#          [[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [1.17818516e-29],
#           [1.00000000e+00],
#           [2.88287699e-29]],
#
#          [[0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [8.76414716e-01]],
#
#          ...,
#
#          [[4.05698438e-38],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00]],
#
#          [[1.03717515e-19],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00]],
#
#          [[1.00000000e+00],
#           [3.08972559e-30],
#           [1.53322552e-34],
#           ...,
#           [0.00000000e+00],
#           [1.07524051e-22],
#           [8.23771015e-38]]],
#
#
#         ...,
#
#
#         [[[9.00376695e-38],
#           [0.00000000e+00],
#           [2.06539369e-07],
#           ...,
#           [1.13576809e-20],
#           [0.00000000e+00],
#           [1.00000000e+00]],
#
#          [[0.00000000e+00],
#           [0.00000000e+00],
#           [1.60962625e-22],
#           ...,
#           [0.00000000e+00],
#           [1.00000000e+00],
#           [1.00000000e+00]],
#
#          [[1.69501301e-31],
#           [0.00000000e+00],
#           [1.21900598e-06],
#           ...,
#           [0.00000000e+00],
#           [1.72665690e-25],
#           [3.14880162e-04]],
#
#          ...,
#
#          [[0.00000000e+00],
#           [1.44992237e-14],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [2.97022602e-23],
#           [2.12675741e-34]],
#
#          [[5.40368095e-30],
#           [0.00000000e+00],
#           [0.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [0.00000000e+00]],
#
#          [[9.74049091e-01],
#           [1.11533351e-08],
#           [6.35322532e-19],
#           ...,
#           [0.00000000e+00],
#           [1.58068172e-28],
#           [0.00000000e+00]]],
#
#
#         [[[7.37936775e-37],
#           [1.45461887e-01],
#           [1.00000000e+00],
#           ...,
#           [1.00000000e+00],
#           [9.93848979e-01],
#           [1.00000000e+00]],
#
#          [[0.00000000e+00],
#           [1.30895570e-38],
#           [1.53214592e-06],
#           ...,
#           [2.96750484e-04],
#           [1.00000000e+00],
#           [4.90825124e-11]],
#
#          [[7.66388331e-21],
#           [1.00000000e+00],
#           [1.00000000e+00],
#           ...,
#           [0.00000000e+00],
#           [9.48311915e-12],
#           [1.90265156e-17]],
#
#          ...,
#
#          [[5.96494215e-24],
#           [2.03689976e-09],
#           [2.68181807e-32],
#           ...,
#           [0.00000000e+00],
#           [1.39040864e-07],
#           [1.04160139e-24]],
#
#          [[5.74705106e-13],
#           [8.21595415e-02],
#           [1.52357015e-27],
#           ...,
#           [0.00000000e+00],
#           [0.00000000e+00],
#           [2.14975441e-31]],
#
#          [[1.00000000e+00],
#           [1.00000000e+00],
#           [2.05904894e-30],
#           ...,
#           [3.02927851e-33],
#           [0.00000000e+00],
#           [0.00000000e+00]]],
#
#
#         [[[1.99026857e-32],
#           [2.10898092e-14],
#           [7.88886527e-23],
#           ...,
#           [1.96563306e-05],
#           [9.99999344e-01],
#           [1.00000000e+00]],
#
#          [[0.00000000e+00],
#           [4.56020275e-25],
#           [7.55845576e-30],
#           ...,
#           [8.80101027e-21],
#           [1.00000000e+00],
#           [1.33139304e-06]],
#
#          [[5.68069584e-34],
#           [7.65399483e-04],
#           [9.99932826e-01],
#           ...,
#           [5.25100250e-18],
#           [1.79798413e-15],
#           [1.00000000e+00]],
#
#          ...,
#
#          [[0.00000000e+00],
#           [1.06161363e-18],
#           [5.84694728e-13],
#           ...,
#           [7.02734185e-18],
#           [4.09656846e-13],
#           [8.66885368e-30]],
#
#          [[2.92145555e-16],
#           [1.96201869e-21],
#           [3.40167122e-21],
#           ...,
#           [0.00000000e+00],
#           [3.93768888e-15],
#           [1.26716718e-34]],
#
#          [[1.58671732e-03],
#           [1.00000000e+00],
#           [1.32398142e-15],
#           ...,
#           [3.86568536e-29],
#           [4.91484747e-18],
#           [0.00000000e+00]]]]], dtype=float32)>

# %% [markdown]
# # other test

# %%
my_model = unet3d_BN((64, 192, 192, 1))

# %%
my_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 192, 19  0           []
#                                 2, 1)]
#
#  conv3d_19 (Conv3D)             (None, 64, 192, 192  896         ['input_2[0][0]']
#                                 , 32)
#
#  batch_normalization (BatchNorm  (None, 64, 192, 192  128        ['conv3d_19[0][0]']
#  alization)                     , 32)
#
#  activation (Activation)        (None, 64, 192, 192  0           ['batch_normalization[0][0]']
#                                 , 32)
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 32, 96, 96,   0          ['activation[0][0]']
#                                 32)
#
#  conv3d_20 (Conv3D)             (None, 32, 96, 96,   55360       ['max_pooling3d_4[0][0]']
#                                 64)
#
#  batch_normalization_1 (BatchNo  (None, 32, 96, 96,   256        ['conv3d_20[0][0]']
#  rmalization)                   64)
#
#  activation_1 (Activation)      (None, 32, 96, 96,   0           ['batch_normalization_1[0][0]']
#                                 64)
#
#  max_pooling3d_5 (MaxPooling3D)  (None, 16, 48, 48,   0          ['activation_1[0][0]']
#                                 64)
#
#  conv3d_21 (Conv3D)             (None, 16, 48, 48,   221312      ['max_pooling3d_5[0][0]']
#                                 128)
#
#  batch_normalization_2 (BatchNo  (None, 16, 48, 48,   512        ['conv3d_21[0][0]']
#  rmalization)                   128)
#
#  activation_2 (Activation)      (None, 16, 48, 48,   0           ['batch_normalization_2[0][0]']
#                                 128)
#
#  max_pooling3d_6 (MaxPooling3D)  (None, 8, 24, 24, 1  0          ['activation_2[0][0]']
#                                 28)
#
#  conv3d_22 (Conv3D)             (None, 8, 24, 24, 2  884992      ['max_pooling3d_6[0][0]']
#                                 56)
#
#  batch_normalization_3 (BatchNo  (None, 8, 24, 24, 2  1024       ['conv3d_22[0][0]']
#  rmalization)                   56)
#
#  activation_3 (Activation)      (None, 8, 24, 24, 2  0           ['batch_normalization_3[0][0]']
#                                 56)
#
#  max_pooling3d_7 (MaxPooling3D)  (None, 4, 12, 12, 2  0          ['activation_3[0][0]']
#                                 56)
#
#  conv3d_23 (Conv3D)             (None, 4, 12, 12, 5  3539456     ['max_pooling3d_7[0][0]']
#                                 12)
#
#  batch_normalization_4 (BatchNo  (None, 4, 12, 12, 5  2048       ['conv3d_23[0][0]']
#  rmalization)                   12)
#
#  activation_4 (Activation)      (None, 4, 12, 12, 5  0           ['batch_normalization_4[0][0]']
#                                 12)
#
#  up_sampling3d (UpSampling3D)   (None, 8, 24, 24, 5  0           ['activation_4[0][0]']
#                                 12)
#
#  conv3d_24 (Conv3D)             (None, 8, 24, 24, 2  3539200     ['up_sampling3d[0][0]']
#                                 56)
#
#  batch_normalization_5 (BatchNo  (None, 8, 24, 24, 2  1024       ['conv3d_24[0][0]']
#  rmalization)                   56)
#
#  activation_5 (Activation)      (None, 8, 24, 24, 2  0           ['batch_normalization_5[0][0]']
#                                 56)
#
#  up_sampling3d_1 (UpSampling3D)  (None, 16, 48, 48,   0          ['activation_5[0][0]']
#                                 256)
#
#  concatenate_4 (Concatenate)    (None, 16, 48, 48,   0           ['up_sampling3d_1[0][0]',
#                                 384)                              'activation_2[0][0]']
#
#  conv3d_25 (Conv3D)             (None, 16, 48, 48,   1327232     ['concatenate_4[0][0]']
#                                 128)
#
#  batch_normalization_6 (BatchNo  (None, 16, 48, 48,   512        ['conv3d_25[0][0]']
#  rmalization)                   128)
#
#  activation_6 (Activation)      (None, 16, 48, 48,   0           ['batch_normalization_6[0][0]']
#                                 128)
#
#  up_sampling3d_2 (UpSampling3D)  (None, 32, 96, 96,   0          ['activation_6[0][0]']
#                                 128)
#
#  conv3d_26 (Conv3D)             (None, 32, 96, 96,   221248      ['up_sampling3d_2[0][0]']
#                                 64)
#
#  batch_normalization_7 (BatchNo  (None, 32, 96, 96,   256        ['conv3d_26[0][0]']
#  rmalization)                   64)
#
#  activation_7 (Activation)      (None, 32, 96, 96,   0           ['batch_normalization_7[0][0]']
#                                 64)
#
#  up_sampling3d_3 (UpSampling3D)  (None, 64, 192, 192  0          ['activation_7[0][0]']
#                                 , 64)
#
#  concatenate_5 (Concatenate)    (None, 64, 192, 192  0           ['up_sampling3d_3[0][0]',
#                                 , 96)                             'activation[0][0]']
#
#  conv3d_27 (Conv3D)             (None, 64, 192, 192  82976       ['concatenate_5[0][0]']
#                                 , 32)
#
#  batch_normalization_8 (BatchNo  (None, 64, 192, 192  128        ['conv3d_27[0][0]']
#  rmalization)                   , 32)
#
#  activation_8 (Activation)      (None, 64, 192, 192  0           ['batch_normalization_8[0][0]']
#                                 , 32)
#
#  conv3d_28 (Conv3D)             (None, 64, 192, 192  33          ['activation_8[0][0]']
#                                 , 1)
#
# ==================================================================================================
# Total params: 9,878,593
# Trainable params: 9,875,649
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
